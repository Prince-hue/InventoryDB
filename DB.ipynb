# %% [markdown]
# ## Creating a connection

# %%
import mysql.connector
new_db = mysql.connector.connect(
    host = 'localhost',
    user = 'root',
    password = 'gateway666'
)

# %%
new_db = mysql.connector.connect(
    host = 'localhost',
    user = 'root',
    password = 'gateway666',
    database = 'workShopInv'
)
new_cursor = new_db.cursor()

# %%
new_sql = 'DROP TABLE IF EXISTS locations'
new_cursor.execute(new_sql)

# %%
var = "CREATE TABLE CostInventory (Description TEXT PRIMARY KEY, StartingQuantity INT NOT NULL CHECK (StartingQuantity >= 0), CabinNumbers INTEGER NOT NULL CHECK (Value >= 0), Classification TEXT NOT NULL);"
new_cursor.execute(var)

# %%
new_cursor.execute('CREATE TABLE students (name VARCHAR(255), code VARCHAR(255))')

# %%
var = "CREATE TABLE CostInventory (Description TEXT PRIMARY KEY, StartingQuantity INT CHECK (StartingQuantity >= 0));"
new_cursor.execute(var)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File c:\Users\pc\AppData\Local\Programs\Python\Python311\Lib\site-packages\mysql\connector\connection_cext.py:611, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     610         query = query.encode("utf-8")
# --> 611     self._cmysql.query(
#     612         query,
#     613         raw=raw,
#     614         buffered=buffered,
#     615         raw_as_string=raw_as_string,
#     616         query_attrs=self._query_attrs,
#     617     )
#     618 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: BLOB/TEXT column 'Description' used in key specification without a key length
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[15], line 2
# ...

# %%
new_cursor.execute('SELECT * FROM trainfile')
new_data = new_cursor.fetchall()

for x in new_data:
    print(x)
# Out:
# (8300.5, 102.47, 2.537, 16.257)
# (8301.0, 106.15, 2.55, 20.246)
# (8301.5, 109.54, 2.564, 24.304)
# (8302.0, 106.48, 2.552, 19.358)
# (8302.5, 100.18, 2.53, 16.254)
# (8303.0, 100.04, 2.53, 15.473)
# (8303.5, 101.65, 2.535, 16.633)
# (8304.0, 103.7, 2.542, 19.608)
# (8304.5, 102.29, 2.537, 14.21)
# (8305.0, 99.1, 2.527, 15.196)
# (8305.5, 96.42, 2.519, 12.179)
# (8306.0, 98.62, 2.526, 16.205)
# (8306.5, 101.75, 2.535, 17.777)
# (8307.0, 103.75, 2.542, 18.32)
# (8307.5, 102.35, 2.537, 16.703)
# (8308.0, 102.61, 2.538, 17.125)
# (8308.5, 103.45, 2.541, 19.433)
# (8309.0, 103.9, 2.542, 19.059)
# (8309.5, 108.6, 2.56, 22.87)
# (8310.0, 113.25, 2.58, 38.971)
# (8310.5, 116.14, 2.594, 89.094)
# (8311.0, 114.63, 2.587, 56.852)
# (8311.5, 111.52, 2.572, 36.456)
# (8312.0, 109.06, 2.562, 27.105)
# (8312.5, 108.32, 2.559, 24.029)
# (8313.0, 106.23, 2.551, 23.161)
# (8313.5, 104.69, 2.545, 20.641)
# (8314.0, 103.72, 2.542, 19.235)
# (8314.5, 105.03, 2.546, 18.396)
# ...

# %%
new_cursor.execute('ALTER TABLE trainfile ADD PRIMARY KEY(DEPTH)')
